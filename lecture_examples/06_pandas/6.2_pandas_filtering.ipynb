# %% [markdown]
# # Pandas filtering
#
# Pandas has powerful features that allow you to do many things with tabular data.
#
# One very basic feature is the ability to filter data. Filtering data is the process of only looking at data that have specific attributes.
#
# <a href=https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html>Pandas examples</a>
#
# ## Demonstrating filtering on the SPC tornado dataset:
#
# Individual tornado reports with time, location, and other information.
#
# We can print out the column names using the ```columns``` method:

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

tor.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4', 'fc'],
#       dtype='object')

# %% [markdown]
# You can read about the column information here: https://www.spc.noaa.gov/wcm/data/SPC_severe_database_description.pdf
#
# We can also look at the types of data in each column using the ```info``` method. This can assure that you are treating columns as numbers if you are running statistics:

# %%
tor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68701 entries, 0 to 68700
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   om      68701 non-null  int64
#  1   yr      68701 non-null  int64
#  2   mo      68701 non-null  int64
#  3   dy      68701 non-null  int64
#  4   date    68701 non-null  object
#  5   time    68701 non-null  object
#  6   tz      68701 non-null  int64
#  7   st      68701 non-null  object
#  8   stf     68701 non-null  int64
#  9   stn     68701 non-null  int64
#  10  mag     68701 non-null  int64
#  11  inj     68701 non-null  int64
#  12  fat     68701 non-null  int64
#  13  loss    68701 non-null  float64
#  14  closs   68701 non-null  float64
#  15  slat    68701 non-null  float64
#  16  slon    68701 non-null  float64
#  17  elat    68701 non-null  float64
#  18  elon    68701 non-null  float64
#  19  len     68701 non-null  float64
#  20  wid     68701 non-null  int64
#  21  ns      68701 non-null  int64
#  22  sn      68701 non-null  int64
#  23  sg      68701 non-null  int64
#  24  f1      68701 non-null  int64
#  25  f2      68701 non-null  int64
#  26  f3      68701 non-null  int64
#  27  f4      68701 non-null  int64
#  28  fc      68701 non-null  int64
# dtypes: float64(7), int64(19), object(3)
# memory usage: 15.2+ MB

# %% [markdown]
# You can run summary statistics using the ```describe``` method.
#
# This method is very useful for looking at quick statistics. However, it demonstrates an important point--you need to understand the importance of these statistics.
#
# The average dy (day) that a tornado happens is 15.9.. why do you think this is?

# %%
tor.describe()
# Out:
#                   om            yr            mo            dy            tz  \
# count   68701.000000  68701.000000  68701.000000  68701.000000  68701.000000
# mean   113188.669801   1991.851691      5.968458     15.930350      3.000961
# std    226612.072728     19.565555      2.444566      8.750166      0.072383
# min         1.000000   1950.000000      1.000000      1.000000      0.000000
# 25%       285.000000   1976.000000      4.000000      8.000000      3.000000
# 50%       588.000000   1995.000000      6.000000     16.000000      3.000000
# 75%      1117.000000   2008.000000      7.000000     24.000000      3.000000
# max    622080.000000   2022.000000     12.000000     31.000000      9.000000
#
#                 stf           stn           mag           inj           fat  \
# count  68701.000000  68701.000000  68701.000000  68701.000000  68701.000000
# mean      29.220957     23.166941      0.671082      1.418524      0.089300
# std       15.013132     31.792126      1.354342     18.113703      1.472035
# min        1.000000      0.000000     -9.000000      0.000000      0.000000
# 25%       18.000000      1.000000      0.000000      0.000000      0.000000
# 50%       28.000000     11.000000      1.000000      0.000000      0.000000
# 75%       42.000000     31.000000      1.000000      0.000000      0.000000
# max       78.000000    232.000000      5.000000   1740.000000    158.000000
#
#        ...           len           wid            ns            sn       sg  \
# count  ...  68701.000000  68701.000000  68701.000000  68701.000000  68701.0
# mean   ...      3.488902    107.758533      1.008763      0.991412      1.0
# std    ...      8.246706    206.841236      0.095054      0.092273      0.0
# min    ...      0.000000      0.000000      1.000000      0.000000      1.0
# 25%    ...      0.120000     20.000000      1.000000      1.000000      1.0
# 50%    ...      0.800000     50.000000      1.000000      1.000000      1.0
# 75%    ...      3.200000    100.000000      1.000000      1.000000      1.0
# max    ...    234.700000   4576.000000      3.000000      1.000000      1.0
#
#                  f1            f2            f3            f4            fc
# count  68701.000000  68701.000000  68701.000000  68701.000000  68701.000000
# mean     104.643528      8.604140      1.687006      0.506732      0.027118
# std       96.749655     38.103913     16.680703      9.162662      0.162427
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       37.000000      0.000000      0.000000      0.000000      0.000000
# 50%       85.000000      0.000000      0.000000      0.000000      0.000000
# 75%      137.000000      0.000000      0.000000      0.000000      0.000000
# max      810.000000    820.000000    710.000000    507.000000      1.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# We should always do some initial checks on our dataset. For example, we expect the data to be from 1950 to 2022. How can we assure this is the case? There are many options, including:
#
# 1. ```unique```
# 2. ```describe```
# 3. ```min``` or ```max```

# %%
tor['yr'].unique()
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
tor['yr'].describe()
# Out:
# count    68701.000000
# mean      1991.851691
# std         19.565555
# min       1950.000000
# 25%       1976.000000
# 50%       1995.000000
# 75%       2008.000000
# max       2022.000000
# Name: yr, dtype: float64

# %%
print("max=", tor['yr'].max(), "min=", tor['yr'].min())
# Out:
# max= 2022 min= 1950

# %% [markdown]
# ### Indexing for the tornado database
#
# We should just keep the default index. Each row is a tornado report, and there are many tornadoes that happen each year. So, unlike the examples in the last slideshow, yr (year) is not a good index column choice.

# %%
tor.yr
# Out:
# 0        1950
# 1        1950
# 2        1950
# 3        1950
# 4        1950
#          ...
# 68696    2022
# 68697    2022
# 68698    2022
# 68699    2022
# 68700    2022
# Name: yr, Length: 68701, dtype: int64

# %% [markdown]
# ### Using conditionals to subset pandas DataFrames
#
# **Please review Conditionals and If Statements**
#
# We can use conditionals to select what rows we want to examine.
#
# Pandas does this by generating True or False arrays based on tests.

# %% [markdown]
# This code prints out the year associated with each tornado report

# %%
print(tor['yr'])
# Out:
# 0        1950
# 1        1950
# 2        1950
# 3        1950
# 4        1950
#          ...
# 68696    2022
# 68697    2022
# 68698    2022
# 68699    2022
# 68700    2022
# Name: yr, Length: 68701, dtype: int64

# %% [markdown]
# We can create a True or False array by running a test like ```tor['yr'] == 1950``` which results in ```True``` for every row that the year is 1950, otherwise ```False```.

# %%
print(tor['yr'] == 1950)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 68696    False
# 68697    False
# 68698    False
# 68699    False
# 68700    False
# Name: yr, Length: 68701, dtype: bool

# %% [markdown]
# We combine this with our DataFrame in one of two ways.
#
# One, set the condition and the resulting ```True``` or ```False``` to a variable and then put it inside square brackets:

# %%
only_in_1950 = tor['yr'] == 1950

tor[only_in_1950]
# Out:
#       om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  \
# 0    192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8
# 1    193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   2.0
# 2    195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   0.1
# 3    196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   0.1
# 4    197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   2.0
# ..   ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...   ...
# 196  181  1950   8   8  1950-08-08  01:00:00   3  MO   29    6  ...   2.0
# 197  182  1950   8   9  1950-08-09  16:55:00   3  WV   54    1  ...   5.0
# 198  189  1950   9  15  1950-09-15  17:45:00   3  OK   40   21  ...   6.8
# 199  190  1950   9  16  1950-09-16  01:30:00   3  OK   40   22  ...   0.1
# 200  191  1950   9  21  1950-09-21  17:30:00   3  NE   31    6  ...  22.5
#
#      wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0     10   1   1   1   25   0   0   0   0
# 1    880   1   1   1   47   0   0   0   0
# 2     10   1   1   1  177   0   0   0   0
# 3     10   1   1   1  209   0   0   0   0
# 4     37   1   1   1  101   0   0   0   0
# ..   ...  ..  ..  ..  ...  ..  ..  ..  ..
# 196   10   1   1   1   77   0   0   0   0
# 197   10   1   1   1  107   0   0   0   0
# 198  100   1   1   1   63   0   0   0   0
# 199   10   1   1   1  121   0   0   0   0
# 200   67   1   1   1  109   0   0   0   0
#
# [201 rows x 29 columns]

# %% [markdown]
# or you can put the test directly into the square brackets:

# %%
tor[tor.yr == 1950]
# Out:
#       om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  \
# 0    192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8
# 1    193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   2.0
# 2    195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   0.1
# 3    196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   0.1
# 4    197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   2.0
# ..   ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...   ...
# 196  181  1950   8   8  1950-08-08  01:00:00   3  MO   29    6  ...   2.0
# 197  182  1950   8   9  1950-08-09  16:55:00   3  WV   54    1  ...   5.0
# 198  189  1950   9  15  1950-09-15  17:45:00   3  OK   40   21  ...   6.8
# 199  190  1950   9  16  1950-09-16  01:30:00   3  OK   40   22  ...   0.1
# 200  191  1950   9  21  1950-09-21  17:30:00   3  NE   31    6  ...  22.5
#
#      wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0     10   1   1   1   25   0   0   0   0
# 1    880   1   1   1   47   0   0   0   0
# 2     10   1   1   1  177   0   0   0   0
# 3     10   1   1   1  209   0   0   0   0
# 4     37   1   1   1  101   0   0   0   0
# ..   ...  ..  ..  ..  ...  ..  ..  ..  ..
# 196   10   1   1   1   77   0   0   0   0
# 197   10   1   1   1  107   0   0   0   0
# 198  100   1   1   1   63   0   0   0   0
# 199   10   1   1   1  121   0   0   0   0
# 200   67   1   1   1  109   0   0   0   0
#
# [201 rows x 29 columns]

# %% [markdown]
# We can combine conditions to get very specific filters. The same rules of combining conditions earlier in the class apply here!
#
# Here is how we get all reports on March 27th, 1950 by defining variables.

# %%
only_in_1950 = tor['yr'] == 1950
only_in_march = tor['mo'] == 3
only_on_the_27th = tor['dy'] == 27

tor[(only_in_1950) & (only_in_march) & (only_on_the_27th)]
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 46  38  1950   3  27  1950-03-27  03:00:00   3  OK   40    2  ...   0.1   77
# 47  39  1950   3  27  1950-03-27  05:00:00   3  MS   28    6  ...   0.1   10
# 48  40  1950   3  27  1950-03-27  06:00:00   3  LA   22    9  ...  15.3   17
# 49  41  1950   3  27  1950-03-27  07:30:00   3  MS   28    7  ...  11.9   10
# 50  42  1950   3  27  1950-03-27  07:45:00   3  MS   28    4  ...  59.3   50
# 51  43  1950   3  27  1950-03-27  07:45:00   3  MS   28    5  ...  31.9   50
# 52  44  1950   3  27  1950-03-27  08:30:00   3  LA   22   10  ...   0.5   27
# 53  45  1950   3  27  1950-03-27  08:45:00   3  MS   28    9  ...   4.7   10
# 54  46  1950   3  27  1950-03-27  11:00:00   3  MS   28    8  ...   0.1   10
# 55  47  1950   3  27  1950-03-27  15:00:00   3  TN   47    3  ...   0.2   10
# 56  48  1950   3  27  1950-03-27  16:30:00   3  IL   17    4  ...   3.0   50
#
#     ns  sn  sg   f1   f2   f3   f4  fc
# 46   1   1   1  121    0    0    0   0
# 47   1   1   1   53    0    0    0   0
# 48   1   1   1   35    0    0    0   0
# 49   1   1   1    7    0    0    0   0
# 50   1   1   1   49  121  123   79   0
# 51   1   1   1   49  121  123  101   0
# 52   1   1   1   37    0    0    0   0
# 53   1   1   1   25    0    0    0   0
# 54   1   1   1  141    0    0    0   0
# 55   1   1   1  177    0    0    0   0
# 56   1   1   1  113    0    0    0   0
#
# [11 rows x 29 columns]

# %% [markdown]
# here is how we do it by placing the conditions directly in the square brackets:

# %%
tor[(tor['yr'] == 1950) & (tor['mo'] == 3) & (tor['dy'] == 27)]
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 46  38  1950   3  27  1950-03-27  03:00:00   3  OK   40    2  ...   0.1   77
# 47  39  1950   3  27  1950-03-27  05:00:00   3  MS   28    6  ...   0.1   10
# 48  40  1950   3  27  1950-03-27  06:00:00   3  LA   22    9  ...  15.3   17
# 49  41  1950   3  27  1950-03-27  07:30:00   3  MS   28    7  ...  11.9   10
# 50  42  1950   3  27  1950-03-27  07:45:00   3  MS   28    4  ...  59.3   50
# 51  43  1950   3  27  1950-03-27  07:45:00   3  MS   28    5  ...  31.9   50
# 52  44  1950   3  27  1950-03-27  08:30:00   3  LA   22   10  ...   0.5   27
# 53  45  1950   3  27  1950-03-27  08:45:00   3  MS   28    9  ...   4.7   10
# 54  46  1950   3  27  1950-03-27  11:00:00   3  MS   28    8  ...   0.1   10
# 55  47  1950   3  27  1950-03-27  15:00:00   3  TN   47    3  ...   0.2   10
# 56  48  1950   3  27  1950-03-27  16:30:00   3  IL   17    4  ...   3.0   50
#
#     ns  sn  sg   f1   f2   f3   f4  fc
# 46   1   1   1  121    0    0    0   0
# 47   1   1   1   53    0    0    0   0
# 48   1   1   1   35    0    0    0   0
# 49   1   1   1    7    0    0    0   0
# 50   1   1   1   49  121  123   79   0
# 51   1   1   1   49  121  123  101   0
# 52   1   1   1   37    0    0    0   0
# 53   1   1   1   25    0    0    0   0
# 54   1   1   1  141    0    0    0   0
# 55   1   1   1  177    0    0    0   0
# 56   1   1   1  113    0    0    0   0
#
# [11 rows x 29 columns]

# %% [markdown]
# Advanced: You can also use the ```query``` method, but the syntax is a bit different:

# %%
tor.query('yr == 1950 & mo == 3 & dy == 27')
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 46  38  1950   3  27  1950-03-27  03:00:00   3  OK   40    2  ...   0.1   77
# 47  39  1950   3  27  1950-03-27  05:00:00   3  MS   28    6  ...   0.1   10
# 48  40  1950   3  27  1950-03-27  06:00:00   3  LA   22    9  ...  15.3   17
# 49  41  1950   3  27  1950-03-27  07:30:00   3  MS   28    7  ...  11.9   10
# 50  42  1950   3  27  1950-03-27  07:45:00   3  MS   28    4  ...  59.3   50
# 51  43  1950   3  27  1950-03-27  07:45:00   3  MS   28    5  ...  31.9   50
# 52  44  1950   3  27  1950-03-27  08:30:00   3  LA   22   10  ...   0.5   27
# 53  45  1950   3  27  1950-03-27  08:45:00   3  MS   28    9  ...   4.7   10
# 54  46  1950   3  27  1950-03-27  11:00:00   3  MS   28    8  ...   0.1   10
# 55  47  1950   3  27  1950-03-27  15:00:00   3  TN   47    3  ...   0.2   10
# 56  48  1950   3  27  1950-03-27  16:30:00   3  IL   17    4  ...   3.0   50
#
#     ns  sn  sg   f1   f2   f3   f4  fc
# 46   1   1   1  121    0    0    0   0
# 47   1   1   1   53    0    0    0   0
# 48   1   1   1   35    0    0    0   0
# 49   1   1   1    7    0    0    0   0
# 50   1   1   1   49  121  123   79   0
# 51   1   1   1   49  121  123  101   0
# 52   1   1   1   37    0    0    0   0
# 53   1   1   1   25    0    0    0   0
# 54   1   1   1  141    0    0    0   0
# 55   1   1   1  177    0    0    0   0
# 56   1   1   1  113    0    0    0   0
#
# [11 rows x 29 columns]

# %% [markdown]
# What happens if we change the last & to an |?
#
# This would give us the rows where the yr was 1950 AND the month was 3.. or all rows where the date was 27

# %%
tor.query('(yr == 1950 & mo == 3) | dy == 27')
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 36         27  1950   2  27  1950-02-27  10:20:00   3  OK   40    1  ...
# 37         29  1950   3  16  1950-03-16  09:15:00   3  FL   12    1  ...
# 38         30  1950   3  19  1950-03-19  07:30:00   3  LA   22    6  ...
# 39         31  1950   3  19  1950-03-19  13:15:00   3  LA   22    7  ...
# 40         32  1950   3  19  1950-03-19  13:15:00   3  LA   22    8  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 68689  621915  2022   9  27  2022-09-27  18:59:00   3  FL   12    0  ...
# 68690  621916  2022   9  27  2022-09-27  19:22:00   3  FL   12    0  ...
# 68691  621917  2022   9  27  2022-09-27  19:30:00   3  FL   12    0  ...
# 68692  621918  2022   9  27  2022-09-27  22:40:00   3  FL   12    0  ...
# 68693  621919  2022   9  27  2022-09-27  23:31:00   3  FL   12    0  ...
#
#          len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 36      2.00   50   1   1   1  109   0   0   0   0
# 37      1.50  150   1   1   1  109   0   0   0   0
# 38      2.00   33   1   1   1   19   0   0   0   0
# 39      1.00   50   1   1   1    5   0   0   0   0
# 40     18.10   27   1   1   1   51  75   0   0   0
# ...      ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 68689   6.98  200   1   1   1   99   0   0   0   0
# 68690   7.48  150   1   1   1   99   0   0   0   0
# 68691   1.39  100   1   1   1   99   0   0   0   0
# 68692   2.83  100   1   1   1   11   0   0   0   0
# 68693   0.06   50   1   1   1   11   0   0   0   0
#
# [2508 rows x 29 columns]

# %% [markdown]
# ### Your turn!

# %% [markdown]
# How many tornadoes are in the tornado dataset?

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

# %% [markdown]
# How many variables/columns are associated with each tornado?

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

# %% [markdown]
# What are the names of these variables/columns?

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

# %% [markdown]
# Can you give summary statistics of the 'mag' column?

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

# %% [markdown]
# Get all rows that have a "mag" of 5. How many rows did you get? Could you figure out what the most common state (e.g., IL, WI, OH, etc.) is for "mag" 5 tornadoes? (HINT try using the ```value_counts``` method)

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

# %% [markdown]
# Get all rows that occurred in Hawaii OR Alaska.  How many occurred in each state?

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")

# %% [markdown]
# Get all rows that occurred on April 27th 2011 and had a "mag" of 3 or greater.  Can you give me the counts for each "mag" category 3 and above on this day?  Based on how rare 3, 4, and 5 'mag's are, do you think this was a mundane day or an historic day? Why or why not?

# %%
import pandas as pd

tor = pd.read_csv("1950-2022_actual_tornadoes.csv")
